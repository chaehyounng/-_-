# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import matplotlib.font_manager as fm

# 시스템에 설치된 한글 폰트 확인
font_path = fm.findfont(fm.FontProperties(family='NanumGothic'))

# 폰트 설정
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
final = pd.read_csv("C:/Users/kimch/Desktop/월빅캠/final.csv")

# %%
final
# Out:
#              정류장  호선_개수  주변_편의시설_개수  노선         위도          경도  주변_장애인시설_개수  \
# 0           가락시장      4          20   3  37.492245  127.117757            0
# 1           강동구청      1          33   8  37.530341  127.120508            1
# 2             개롱      1          23   5  37.498079  127.134820            0
# 3             거여      1          18   5  37.493105  127.144150            3
# 4           경찰병원      1          22   3  37.495918  127.124540            0
# ..           ...    ...         ...  ..        ...         ...          ...
# 236   충정로(경기대입구)      4          18   2  37.559704  126.964378            2
# 237           홍제      1          48   3  37.589066  126.943736            0
# 238  미아(서울사이버대학)      1          64   4  37.626670  127.025983            4
# 239        미아사거리      1          31   4  37.613292  127.030053            0
# 240     수유(강북구청)      1          77   4  37.638052  127.025732            6
#
# ...

# %%
# 상관관계 계산하기 위해 수치형 변수만 추출
final_n = final[['호선_개수', '주변_편의시설_개수', '노선', '위도', '경도', '주변_장애인시설_개수', '8월_장애인_승객수', '9월_장애인_승객수', '10월_장애인_승객수', '평균_장애인_승객수']]

# %%
corr = final_n.corr()

fig, ax = plt.subplots()
fig.set_size_inches(15, 12)
sns.heatmap(corr, annot=True, fmt=".2f", cmap="Blues", center=0, ax=ax)

plt.show()
